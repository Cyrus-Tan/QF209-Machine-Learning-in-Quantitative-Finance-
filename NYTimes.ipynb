# %%
from pynytimes import NYTAPI
api_key = "FgcZ4QrpmREscAuxViMh87MSQPF3gk6S"
nyt = NYTAPI(api_key, parse_dates=True)

# %%
news_desk = ["business", "financial"]
articles = nyt.article_search(
    options = {
        "news_desk" : news_desk
        }
    )
articles
# Out:
# [{'abstract': 'What the journey of a Union Pacific locomotive reveals about Trump’s plans for the North American economy.',
#   'web_url': 'https://www.nytimes.com/2018/03/30/business/economy/trade-nafta-union-pacific.html',
#   'snippet': 'What the journey of a Union Pacific locomotive reveals about Trump’s plans for the North American economy.',
#   'lead_paragraph': 'CHICAGO — If North America were a factory, Union Pacific would be its biggest conveyor belt.',
#   'print_section': 'B',
#   'print_page': '1',
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2018/03/08/business/08DC-RAIL-1/merlin_133154307_fe8ff477-7189-469b-8b94-df65f7886d89-articleLarge.jpg',
#     'height': 480,
#     'width': 600,
#     'legacy': {'xlarge': 'images/2018/03/08/business/08DC-RAIL-1/merlin_133154307_fe8ff477-7189-469b-8b94-df65f7886d89-articleLarge.jpg',
# ...
